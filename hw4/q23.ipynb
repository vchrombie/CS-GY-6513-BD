# %%
from pymongo import MongoClient, GEOSPHERE

from pprint import pprint
from datetime import datetime

# %%
username = "vt2182"
password = "vt2182"
host = "mongo-csgy-6513-spring.db"
auth_database = "vt2182"

# %%
client = MongoClient(f"mongodb://{username}:{password}@{host}/{auth_database}")

# %%
db = client[auth_database]
db
# Out:
# Database(MongoClient(host=['mongo-csgy-6513-spring.db:27017'], document_class=dict, tz_aware=False, connect=True), 'vt2182')

# %%
db.list_collection_names()
# Out:
# ['worldcities',
#  'durham_restaurants',
#  'meteorites',
#  'durham_foreclosures',
#  'restaurants']

# %% [markdown]
# ## Q2. Restaurant foreclosures in North Carolina
#
# Some Background: geospatial logic is possible in MongoDB using the geopastial library/facilities. https://docs.mongodb.com/manual/geospatial-queries/
#
# Datasets:
# - `durham-nc-foreclosure-2006-2016.json`
# - `Restaurants_in_Durham_County_NC.csv`
#
# Find the number of foreclosures within the _polygon_ defined as all restaurants where `Rpt_Area_Desc=”Food Service”` and `Seats>=100`.

# %%
foreclosures = db["durham_foreclosures"]
foreclosures.count_documents({})
# Out:
# 1948

# %%
pprint(foreclosures.find_one())
# Out:
# {'_id': ObjectId('64447e0248ae79980f06c9f9'),
#  'datasetid': 'foreclosure-2006-2016',
#  'fields': {'address': '217 E CORPORATION ST',
#             'geocode': [36.0013755, -78.8922549],
#             'parcel_number': '110138',
#             'year': '2006'},
#  'geometry': {'coordinates': [-78.8922549, 36.0013755], 'type': 'Point'},
#  'record_timestamp': '2017-03-06T12:41:48-05:00',
#  'recordid': '629979c85b1cc68c1d4ee8cc351050bfe3592c62'}

# %%
restaurants = db["durham_restaurants"]
restaurants.count_documents({})
# Out:
# 4944

# %%
pprint(restaurants.find_one())
# Out:
# {'Closing_Date': '',
#  'Est_Group_Desc': 'Nursing Home',
#  'Hours_Of_Operation': '',
#  'ID': 58123,
#  'Insp_Freq': 4,
#  'Opening_Date': '2003-10-15',
#  'Premise_Address1': '4434 BEN FRANKLIN BLVD',
#  'Premise_Address2': '',
#  'Premise_City': 'DURHAM',
#  'Premise_Name': 'BROOKDALE DURHAM IFS',
#  'Premise_Phone': '(919) 479-9966',
#  'Premise_State': 'NC',
#  'Premise_Zip': 27704,
#  'Risk': 4,
#  'Rpt_Area_Desc': 'Food Service',
#  'Seats': 350,
#  'Sewage': '3 - Municipal/Community',
#  'Smoking_Allowed': 'NO',
#  'Status': 'ACTIVE',
#  'Transitional_Type_Desc': 'FOOD',
#  'Type_Description': '16 - Institutional Food Service',
#  'Water': '5 - Municipal/Community',
#  '_id': ObjectId('64447cea904e19136eb23ad9'),
#  'geolocation': '36.0467802, -78.8895483'}

# %%
# Create a 2dsphere index for the 'geometry' field if it doesn't exist
foreclosures.create_index([("geometry", GEOSPHERE)], background=True)
# Out:
# 'geometry_2dsphere'

# %%
pprint(foreclosures.find_one())
# Out:
# {'_id': ObjectId('64447e0248ae79980f06c9f9'),
#  'datasetid': 'foreclosure-2006-2016',
#  'fields': {'address': '217 E CORPORATION ST',
#             'geocode': [36.0013755, -78.8922549],
#             'parcel_number': '110138',
#             'year': '2006'},
#  'geometry': {'coordinates': [-78.8922549, 36.0013755], 'type': 'Point'},
#  'record_timestamp': '2017-03-06T12:41:48-05:00',
#  'recordid': '629979c85b1cc68c1d4ee8cc351050bfe3592c62'}

# %%
# Filter the restaurant dataset based on the conditions
filtered_restaurants = list(restaurants.find({"Rpt_Area_Desc": "Food Service", "Seats": {"$gte": 100}}))
len(filtered_restaurants)
# Out:
# 464

# %%
pprint(filtered_restaurants[0])
# Out:
# {'Closing_Date': '',
#  'Est_Group_Desc': 'Nursing Home',
#  'Hours_Of_Operation': '',
#  'ID': 58123,
#  'Insp_Freq': 4,
#  'Opening_Date': '2003-10-15',
#  'Premise_Address1': '4434 BEN FRANKLIN BLVD',
#  'Premise_Address2': '',
#  'Premise_City': 'DURHAM',
#  'Premise_Name': 'BROOKDALE DURHAM IFS',
#  'Premise_Phone': '(919) 479-9966',
#  'Premise_State': 'NC',
#  'Premise_Zip': 27704,
#  'Risk': 4,
#  'Rpt_Area_Desc': 'Food Service',
#  'Seats': 350,
#  'Sewage': '3 - Municipal/Community',
#  'Smoking_Allowed': 'NO',
#  'Status': 'ACTIVE',
#  'Transitional_Type_Desc': 'FOOD',
#  'Type_Description': '16 - Institutional Food Service',
#  'Water': '5 - Municipal/Community',
#  '_id': ObjectId('64447cea904e19136eb23ad9'),
#  'geolocation': '36.0467802, -78.8895483'}

# %%
pprint(filtered_restaurants[0]['geolocation'])
# Out:
# '36.0467802, -78.8895483'

# %%
polygon_coords = []

for row in filtered_restaurants:
    if row['geolocation']:
        latitude, longitude = map(float, row['geolocation'].split(', '))
    else:
        continue
    
    polygon_coords.append([longitude, latitude])

# %%
lonMin = min(coord[0] for coord in polygon_coords)
lonMax = max(coord[0] for coord in polygon_coords)
latMin = min(coord[1] for coord in polygon_coords)
latMax = max(coord[1] for coord in polygon_coords)

# %%
# number of foreclosures within the polygon defined as all restaurants 
# where `Rpt_Area_Desc=”Food Service”` and `Seats>=100`

foreclosures_within_polygon = foreclosures.find({
    "geometry":{
        "$geoWithin":{
            "$geometry":{
                "type":"Polygon",
                "coordinates":[[
                    [lonMin,latMin],
                    [lonMin,latMax],
                    [lonMax,latMax],
                    [lonMax,latMin],
                    [lonMin,latMin]
                ]]
            }
        }
    }
})

count=0
for foreclosure in foreclosures_within_polygon:
    count += 1

print("Number of foreclosures within the polygon:", count)
# Out:
# Number of foreclosures within the polygon: 1830

# %% [markdown]
# # Q3. Extra Credit
#
# Datasets:
# - `meteorites.json`
# - `worldcities.csv`
#
# Use the MongoDB geospatial facilities to *find the nearest city to each meteorite “fallen” (not found) since the year 1950, inclusive*. Distance is between coordinates should be a straight line.
#
# Note:
# - `worldcities` is a CSV file. You will need to import into MongoDB AND clean-up the double quotes.
# - Use the `$near` operator and select this closest entry per city.

# %%
meteorites = db["meteorites"]
meteorites.count_documents({})
# Out:
# 2000

# %%
pprint(meteorites.find_one())
# Out:
# {'_id': ObjectId('6444776e8eccd146808a65c1'),
#  'fall': 'Fell',
#  'geolocation': {'coordinates': [10.23333, 56.18333], 'type': 'Point'},
#  'id': '2',
#  'mass': '720',
#  'name': 'Aarhus',
#  'nametype': 'Valid',
#  'recclass': 'H6',
#  'reclat': '56.183330',
#  'reclong': '10.233330',
#  'year': '1951-01-01T00:00:00.000'}

# %%
worldcities = db["worldcities"]
worldcities.count_documents({})
# Out:
# 25786

# %%
# Add city_location field as a GeoJSON Point
worldcities.update_many(
    {},
    [
        {
            "$set": {
                "city_location": {
                    "type": "Point",
                    "coordinates": ["$lng", "$lat"]
                }
            }
        }
    ]
)

# %%
pprint(worldcities.find_one())
# Out:
# {'_id': ObjectId('6444778e99954515fc972d86'),
#  'admin_name': 'Malishevë',
#  'capital': 'admin',
#  'city': 'Malishevë',
#  'city_ascii': 'Malisheve',
#  'city_location': {'coordinates': [20.7458, 42.4822], 'type': 'Point'},
#  'country': 'Kosovo',
#  'id': 1901597212,
#  'iso2': 'XK',
#  'iso3': 'XKS',
#  'lat': 42.4822,
#  'lng': 20.7458,
#  'population': ''}

# %%
# Create 2dsphere indexes
meteorites.create_index([('geolocation', '2dsphere')])
worldcities.create_index([('city_location', '2dsphere')])
# Out:
# 'city_location_2dsphere'

# %%
# find the nearest city to each meteorite “fallen” (not found) since the year 1950, inclusive

filtered_meteorites = meteorites.find({
    "fall": "Fell",
    "year": {
        "$gte": datetime.strptime('1950, 1, 1', '%Y, %m, %d').isoformat(timespec='milliseconds')
    },
    "geolocation": {
        "$exists": True
    }
})

for meteorite in filtered_meteorites:
    nearest_city = worldcities.find_one({
        "city_location": {
            "$near": {
                "$geometry": {
                    "type": "Point",
                    "coordinates": meteorite["geolocation"]["coordinates"],
                },
            },
        },
    })

    print("meteorite {} and nearest city {}".format(meteorite['name'], nearest_city["city"]))
# Out:
# meteorite Aarhus and nearest city Århus
# meteorite Abee and nearest city Athabasca
# meteorite Acapulco and nearest city Acapulco
# meteorite Aioun el Atrouss and nearest city Ayoun el Atrous
# meteorite Akwanga and nearest city Lafia
# meteorite Akyumak and nearest city Ağrı
# meteorite Al Rais and nearest city Medina
# meteorite Al Zarnkh and nearest city En Nuhud
# meteorite Alby sur Chéran and nearest city Annecy
# meteorite Allende and nearest city Hidalgo del Parral
# meteorite Almahata Sitta and nearest city Wadi Halfa
# meteorite Alta'ameem and nearest city Kirkuk
# meteorite Andreevka and nearest city Kramatorsk
# meteorite Anlong and nearest city Xingyi
# meteorite Aomori and nearest city Aomori
# meteorite Arbol Solo and nearest city San Luis
# meteorite Arroyo Aguiar and nearest city Santa Fe
# meteorite Ash Creek and nearest city Lacy-Lakeview
# meteorite Avanhandava and nearest city Penápolis
# meteorite Awere and nearest city Kole
# meteorite Ban Rong Du and nearest city Phetchabun
# meteorite Barwell and nearest city Leicester
# meteorite Baszkówka and nearest city Warsaw
# meteorite Bassikounou and nearest city Sokolo
# meteorite Battle Mountain and nearest city Winnemucca
# meteorite Bawku and nearest city Bawku
# meteorite Bells and nearest city Sherman
# meteorite Benguerir and nearest city Marrakesh
# meteorite Beni M'hira and nearest city Tataouine
# meteorite Bensour and nearest city Marrakesh
# meteorite Berduc and nearest city Paysandú
# meteorite Berthoud and nearest city Berthoud
# meteorite Bhawad and nearest city Jodhpur
# meteorite Bilanga and nearest city Koupéla
# meteorite Binningup and nearest city Bunbury
# meteorite Bo Xian and nearest city Shangqiu
# meteorite Bogou and nearest city Fada Ngourma
# meteorite Boumdeid (2003) and nearest city Tidjikdja
# meteorite Boumdeid (2011) and nearest city Kiffa
# meteorite Bovedy and nearest city Craigavon
# meteorite Breitscheid and nearest city Gießen
# meteorite Bruderheim and nearest city Edmonton
# meteorite Bukhara and nearest city Kogon
# meteorite Bunburra Rockhole and nearest city Ceduna
# meteorite Burnwell and nearest city Pikeville
# meteorite Buzzard Coulee and nearest city North Battleford
# meteorite Cali and nearest city Cali
# meteorite Campos Sales and nearest city Crato
# meteorite Çanakkale and nearest city Çanakkale
# meteorite Canon City and nearest city Cañon City
# meteorite Carancas and nearest city Desaguadero
# meteorite Ceniceros and nearest city Hidalgo del Parral
# meteorite Centerville and nearest city Tea
# meteorite Chadong and nearest city Tongren
# meteorite Changde and nearest city Changde
# meteorite Chela and nearest city Kahama
# meteorite Chelyabinsk and nearest city Yemanzhelinsk
# meteorite Chergach  and nearest city Taoudenni
# meteorite Chernyi Bor and nearest city Mahilyow
# meteorite Chiang Khan and nearest city Loei
# meteorite Chisenga and nearest city Chitipa
# meteorite Chitado and nearest city Chitado
# meteorite Cilimus and nearest city Tasikmalaya
# meteorite Claxton and nearest city Statesboro
# meteorite Chitenay and nearest city Tours
# meteorite Coleman and nearest city Clare
# meteorite Conquista and nearest city Uberaba
# meteorite Dahmani and nearest city Qasserine
# meteorite Dashoguz and nearest city Daşoguz
# meteorite Daule and nearest city Guayaquil
# meteorite Denver and nearest city Denver
# meteorite Dergaon and nearest city Jorhat
# meteorite Desuri and nearest city Pali
# meteorite Devgaon and nearest city Warangal
# meteorite Devri-Khera and nearest city Kota
# meteorite Dhajala and nearest city Rajkot
# meteorite Didim and nearest city Söke
# meteorite Distrito Quebracho and nearest city Paraná
# meteorite Djermaia and nearest city Ndjamena
# meteorite Djoumine and nearest city Béja
# meteorite Dong Ujimqin Qi and nearest city Bairin Zuoqi
# meteorite Dongtai and nearest city Yancheng
# meteorite Dosso and nearest city Dosso
# meteorite Dowa and nearest city Dowa
# meteorite Dubrovnik and nearest city Herceg-Novi
# meteorite Dunbogan and nearest city Port Macquarie
# meteorite Dunhua and nearest city Dunhua
# meteorite Dwaleni and nearest city Nhlangano
# meteorite Ehole and nearest city Oshikango
# meteorite El Idrissia and nearest city Djelfa
# meteorite El Paso de Aguila and nearest city Matamoros
# meteorite El Tigre and nearest city Ciudad Guzman
# meteorite Elbert and nearest city Castle Rock
# meteorite Elenovka and nearest city Donetsk
# meteorite Enshi and nearest city Fengjie
# meteorite Essebi and nearest city Arua
# meteorite Fermo and nearest city Ancona
# meteorite Fuyang and nearest city Fuyang
# meteorite Galim (a) and nearest city Tibati
# meteorite Galim (b) and nearest city Tibati
# meteorite Galkiv and nearest city Chernihiv
# meteorite Gao-Guenie and nearest city Sapouy
# meteorite Garland and nearest city Tremonton
# meteorite Gashua and nearest city Gashua
# meteorite Geidam and nearest city Diffa
# meteorite Gasseltepaoua and nearest city Djibo
# meteorite Glanerbrug and nearest city Münster
# meteorite Glatton and nearest city Peterborough
# meteorite Gorlovka and nearest city Horlivka
# meteorite Grefsheim and nearest city Hamar
# meteorite Granes and nearest city Perpignan
# meteorite Grimsby and nearest city Hamilton
# meteorite Guangmingshan and nearest city Zhuanghe
# meteorite Guangrao and nearest city Buizhou
# meteorite Guangnan and nearest city Xingyi
# meteorite Guibga and nearest city Kaya
# meteorite Gujargaon and nearest city Ujjain
# meteorite Gujba and nearest city Damaturu
# meteorite Gursum and nearest city Harar
# meteorite Hamlet and nearest city Plymouth
# meteorite Harleton and nearest city Marshall
# meteorite Haverö and nearest city Turku
# meteorite Hiroshima and nearest city Hiroshima
# meteorite Hoima and nearest city Hoima
# meteorite Hökmark and nearest city Skellefteå
# meteorite Hotse and nearest city Puyang
# meteorite Hoxie and nearest city Colby
# meteorite Huaxi and nearest city Guiyang
# meteorite Ibitira and nearest city Divinópolis
# meteorite Idutywa and nearest city Umtata
# meteorite Iguaracu and nearest city Maringá
# meteorite Ijopega and nearest city Goroka
# meteorite Inner Mongolia and nearest city Hohhot
# meteorite Innisfree and nearest city Vegreville
# meteorite Ishinga and nearest city Tukuyu
# meteorite Ipiranga and nearest city Foz do Iguaçu
# meteorite Itqiy and nearest city Bir Mogrein
# meteorite Jartai and nearest city Wuhai
# meteorite Jesenice and nearest city Jesenice
# meteorite Jiange and nearest city Mianyang
# meteorite Jilin and nearest city Jiutai
# meteorite Jodiya and nearest city Rajkot
# meteorite Jolomba and nearest city Calucinga
# meteorite Jumapalo and nearest city Madiun
# meteorite Junan and nearest city Linyi
# meteorite Juromenha and nearest city Badajoz
# meteorite Kabo and nearest city Kano
# meteorite Juancheng and nearest city Heze
# meteorite Kaidun and nearest city Al Mukalla
# meteorite Kalaba and nearest city Moba
# meteorite Kandahar (Afghanistan) and nearest city Kandahar
# meteorite Kaprada and nearest city Silvassa
# meteorite Karatu and nearest city Oldeani
# meteorite Karloowala and nearest city Dera Ismail Khan
# meteorite Kasauli and nearest city Muzaffarnagar
# meteorite Kavarpura and nearest city Kota
# meteorite Katagum and nearest city Azare
# meteorite Kayakent and nearest city Polatlı
# meteorite Kemer and nearest city Rodos
# meteorite Kendrapara and nearest city Cuttack
# meteorite Kidairat and nearest city En Nuhud
# meteorite Kiel and nearest city Kiel
# meteorite Kiffa and nearest city Kiffa
# meteorite Kilabo and nearest city Nguru
# meteorite Kingai and nearest city Niyala
# meteorite Kitchener and nearest city Kitchener
# meteorite Kobe and nearest city Kōbe
# meteorite Kokubunji and nearest city Takamatsu
# meteorite Košice and nearest city Košice
# meteorite Kulak and nearest city Chaman
# meteorite Kunya-Urgench and nearest city Koneurgench
# meteorite Kutais and nearest city Apsheronsk
# meteorite La Criolla and nearest city Concordia
# meteorite Lahrauli and nearest city Faizabad
# meteorite Lanxi and nearest city Lanxi
# meteorite Laochenzhen and nearest city Jieshou
# meteorite Leighlinbridge and nearest city Kilkenny
# meteorite Lichtenberg and nearest city Mahikeng
# meteorite Lishui and nearest city Maanshan
# meteorite Lohawat and nearest city Jodhpur
# meteorite Lost City and nearest city Tahlequah
# meteorite Lorton and nearest city Alexandria
# meteorite Louisville and nearest city Shively
# meteorite Lunan and nearest city Kunming
# meteorite Lusaka and nearest city Moba
# meteorite Madhipura and nearest city Rajbiraj
# meteorite Machinga and nearest city Zomba
# meteorite Magombedze and nearest city Masvingo
# meteorite Mahadevpur and nearest city Dibrugarh
# meteorite Maigatari-Danduma and nearest city Dutse
# meteorite Malakal and nearest city Malakal
# meteorite Manych and nearest city Elista
# meteorite Maribo and nearest city Svendborg
# meteorite Marilia and nearest city Marília
# meteorite Maryville and nearest city Farragut
# meteorite Maromandia and nearest city Ambanja
# meteorite Mason Gully and nearest city Sekondi
# meteorite Mayo Belwa and nearest city Yola
# meteorite Medanitos and nearest city Belen
# meteorite Mbale and nearest city Mbale
# meteorite Messina and nearest city Messina
# meteorite Mianchi and nearest city Luoyang
# meteorite Mifflin and nearest city Platteville
# meteorite Mihonoseki and nearest city Matsue
# meteorite Millbillillie and nearest city Meekatharra
# meteorite Min-Fan-Zhun and nearest city Nantong
# meteorite Monahans (1998) and nearest city Monahans
# meteorite Molteno and nearest city Aliwal North
# meteorite Monte das Fortes and nearest city Beja
# meteorite Monze and nearest city Mazabuka
# meteorite Morávka and nearest city Ostrava
# meteorite Moss and nearest city Moss
# meteorite Mount Tazerzait and nearest city Arlit
# meteorite Murray and nearest city Murray
# meteorite Murchison and nearest city Shepparton
# meteorite Muzaffarpur and nearest city Muzaffarpur
# meteorite Nadiabondi and nearest city Fada Ngourma
# meteorite Nantong and nearest city Nantong
# meteorite Naragh and nearest city Kashan
# meteorite Neagari and nearest city Kanazawa
# meteorite Nejo and nearest city Gimbi
# meteorite Neuschwanstein and nearest city Innsbruck
# meteorite New Orleans and nearest city Westwego
# meteorite New Halfa and nearest city Kassala
# meteorite Ningbo and nearest city Ningbo
# meteorite Nikolskoe and nearest city Solnechnogorsk
# meteorite Ningqiang and nearest city Guangyuan
# meteorite Noblesville and nearest city Noblesville
# meteorite Noventa Vicentina and nearest city Verona
# meteorite Nuevo Mercurio and nearest city Parras
# meteorite Ohuma and nearest city Abakaliki
# meteorite Okabe and nearest city Maebashi
# meteorite Omolon and nearest city Omolon
# meteorite Ouadangou and nearest city Bogandé
# meteorite Oued el Hadjar and nearest city Marrakesh
# meteorite Orlando and nearest city Winter Park
# meteorite Ourique and nearest city Portimão
# meteorite Oum Dreyga and nearest city Fderik
# meteorite Palca de Aparzo and nearest city Humahuaca
# meteorite Parambu and nearest city Tauá
# meteorite Paranaiba and nearest city Paranaíba
# meteorite Park Forest and nearest city Park Forest
# meteorite Patora and nearest city Raipur
# meteorite Patrimonio and nearest city Frutal
# meteorite Pavel and nearest city Turnovo
# meteorite Pê and nearest city Diébougou
# meteorite Peace River and nearest city Peace River
# meteorite Peckelsheim and nearest city Kassel
# meteorite Peekskill and nearest city Peekskill
# meteorite Pétèlkolé and nearest city Dori
# meteorite Piancaldoli and nearest city Bologna
# meteorite Piplia Kalan and nearest city Pali
# meteorite Pleşcoi and nearest city Buzău
# meteorite Portales Valley and nearest city Portales
# meteorite Pribram and nearest city Pizen
# meteorite Puerto Lápice and nearest city Toledo
# meteorite Qidong and nearest city Nantong
# meteorite Qingzhen and nearest city Guiyang
# meteorite Quija and nearest city Jiutai
# meteorite Raco and nearest city Tucumán
# meteorite Raghunathpura and nearest city Alwar
# meteorite Rahimyar Khan and nearest city Sadiqabad
# meteorite Ramsdorf and nearest city Münster
# meteorite Ras Tanura and nearest city Al-Qatif
# meteorite Red Canyon Lake and nearest city Sonora
# meteorite Revelstoke and nearest city Revelstoke
# meteorite Richland Springs and nearest city Brady
# meteorite Ruhobobo and nearest city Kisoro
# meteorite Sabrum and nearest city Comilla
# meteorite Saint-Séverin and nearest city Bordeaux
# meteorite Salem and nearest city Keizer
# meteorite Salzwedel and nearest city Braunschweig
# meteorite San Michele and nearest city Ancona
# meteorite San Juan Capistrano and nearest city San Juan Capistrano
# meteorite San Pedro de Quiles and nearest city Combarbalá
# meteorite San Pedro Jacuaro and nearest city Ciudad Hidalgo
# meteorite Santa Lucia (2008) and nearest city San Juan
# meteorite São Jose do Rio Preto and nearest city São José do Rio Preto
# meteorite Sayama and nearest city Kawagoe
# meteorite Schenectady and nearest city Scotia
# meteorite Senboku and nearest city Akita
# meteorite Seoni and nearest city Nagpur
# meteorite Sfax and nearest city Sfax
# meteorite Shuangyang and nearest city Changchun
# meteorite Silao and nearest city Guanajuato
# meteorite Sinnai and nearest city Cagliari
# meteorite Sivas and nearest city Tokat
# meteorite Sixiangkou and nearest city Taizhou
# meteorite Sheyang and nearest city Yancheng
# meteorite Soheria and nearest city Gorakhpur
# meteorite Sołtmany and nearest city Ełk
# meteorite Songyuan and nearest city Fuyu
# meteorite St. Louis and nearest city Jennings
# meteorite St.-Chinian and nearest city Béziers
# meteorite Ste. Marguerite and nearest city Lille
# meteorite Sterlitamak and nearest city Sterlitamak
# meteorite Stratford and nearest city Bridgeport
# meteorite St-Robert and nearest city Joliette
# meteorite Suchy Dul and nearest city Hradec Králové
# meteorite Suizhou and nearest city Anlu
# meteorite Sulagiri and nearest city Kolar
# meteorite Sutter's Mill and nearest city Placerville
# meteorite Sylacauga and nearest city Sylacauga
# meteorite Tagish Lake and nearest city Whitehorse
# meteorite Tahara and nearest city Hamamatsu
# meteorite Tambakwatu and nearest city Pasuruan
# meteorite Tamdakht and nearest city Marrakesh
# meteorite Taonan and nearest city Taonan
# meteorite Tathlith and nearest city Qal at Bishah
# meteorite Thal and nearest city Bannu
# meteorite Thika and nearest city Thika
# meteorite Thuathe and nearest city Maseru
# meteorite Tianzhang and nearest city Huaiyin
# meteorite Tissint and nearest city Tiznit
# meteorite Tillaberi and nearest city Tillabéri
# meteorite Aarhus and nearest city Århus
# meteorite Abee and nearest city Athabasca
# meteorite Acapulco and nearest city Acapulco
# meteorite Aioun el Atrouss and nearest city Ayoun el Atrous
# meteorite Akwanga and nearest city Lafia
# meteorite Akyumak and nearest city Ağrı
# meteorite Al Zarnkh and nearest city En Nuhud
# meteorite Al Rais and nearest city Medina
# meteorite Alby sur Chéran and nearest city Annecy
# meteorite Allende and nearest city Hidalgo del Parral
# meteorite Almahata Sitta and nearest city Wadi Halfa
# meteorite Alta'ameem and nearest city Kirkuk
# meteorite Andreevka and nearest city Kramatorsk
# meteorite Anlong and nearest city Xingyi
# meteorite Aomori and nearest city Aomori
# meteorite Arbol Solo and nearest city San Luis
# meteorite Arroyo Aguiar and nearest city Santa Fe
# meteorite Ash Creek and nearest city Lacy-Lakeview
# meteorite Avanhandava and nearest city Penápolis
# meteorite Awere and nearest city Kole
# meteorite Ban Rong Du and nearest city Phetchabun
# meteorite Barwell and nearest city Leicester
# meteorite Bassikounou and nearest city Sokolo
# meteorite Baszkówka and nearest city Warsaw
# meteorite Bawku and nearest city Bawku
# meteorite Battle Mountain and nearest city Winnemucca
# meteorite Bells and nearest city Sherman
# meteorite Benguerir and nearest city Marrakesh
# meteorite Beni M'hira and nearest city Tataouine
# meteorite Bensour and nearest city Marrakesh
# meteorite Berduc and nearest city Paysandú
# meteorite Berthoud and nearest city Berthoud
# meteorite Bhawad and nearest city Jodhpur
# meteorite Bilanga and nearest city Koupéla
# meteorite Binningup and nearest city Bunbury
# meteorite Bo Xian and nearest city Shangqiu
# meteorite Bogou and nearest city Fada Ngourma
# meteorite Boumdeid (2011) and nearest city Kiffa
# meteorite Boumdeid (2003) and nearest city Tidjikdja
# meteorite Bovedy and nearest city Craigavon
# meteorite Breitscheid and nearest city Gießen
# meteorite Bruderheim and nearest city Edmonton
# meteorite Bukhara and nearest city Kogon
# meteorite Bunburra Rockhole and nearest city Ceduna
# meteorite Burnwell and nearest city Pikeville
# meteorite Buzzard Coulee and nearest city North Battleford
# meteorite Cali and nearest city Cali
# meteorite Çanakkale and nearest city Çanakkale
# meteorite Campos Sales and nearest city Crato
# meteorite Canon City and nearest city Cañon City
# meteorite Carancas and nearest city Desaguadero
# meteorite Centerville and nearest city Tea
# meteorite Ceniceros and nearest city Hidalgo del Parral
# meteorite Chadong and nearest city Tongren
# meteorite Changde and nearest city Changde
# meteorite Chela and nearest city Kahama
# meteorite Chelyabinsk and nearest city Yemanzhelinsk
# meteorite Chergach  and nearest city Taoudenni
# meteorite Chernyi Bor and nearest city Mahilyow
# meteorite Chiang Khan and nearest city Loei
# meteorite Chisenga and nearest city Chitipa
# meteorite Chitado and nearest city Chitado
# meteorite Chitenay and nearest city Tours
# meteorite Cilimus and nearest city Tasikmalaya
# meteorite Claxton and nearest city Statesboro
# meteorite Coleman and nearest city Clare
# meteorite Conquista and nearest city Uberaba
# meteorite Dahmani and nearest city Qasserine
# meteorite Dashoguz and nearest city Daşoguz
# meteorite Daule and nearest city Guayaquil
# meteorite Dergaon and nearest city Jorhat
# meteorite Denver and nearest city Denver
# meteorite Devgaon and nearest city Warangal
# meteorite Desuri and nearest city Pali
# meteorite Devri-Khera and nearest city Kota
# meteorite Dhajala and nearest city Rajkot
# meteorite Didim and nearest city Söke
# meteorite Distrito Quebracho and nearest city Paraná
# meteorite Djermaia and nearest city Ndjamena
# meteorite Djoumine and nearest city Béja
# meteorite Dong Ujimqin Qi and nearest city Bairin Zuoqi
# meteorite Dongtai and nearest city Yancheng
# meteorite Dosso and nearest city Dosso
# meteorite Dowa and nearest city Dowa
# meteorite Dubrovnik and nearest city Herceg-Novi
# meteorite Dunbogan and nearest city Port Macquarie
# meteorite Dunhua and nearest city Dunhua
# meteorite Dwaleni and nearest city Nhlangano
# meteorite Ehole and nearest city Oshikango
# meteorite El Idrissia and nearest city Djelfa
# meteorite El Tigre and nearest city Ciudad Guzman
# meteorite Elbert and nearest city Castle Rock
# meteorite El Paso de Aguila and nearest city Matamoros
# meteorite Elenovka and nearest city Donetsk
# meteorite Enshi and nearest city Fengjie
# meteorite Essebi and nearest city Arua
# meteorite Fermo and nearest city Ancona
# meteorite Fuyang and nearest city Fuyang
# meteorite Galim (a) and nearest city Tibati
# meteorite Galim (b) and nearest city Tibati
# meteorite Galkiv and nearest city Chernihiv
# meteorite Gao-Guenie and nearest city Sapouy
# meteorite Garland and nearest city Tremonton
# meteorite Gashua and nearest city Gashua
# meteorite Geidam and nearest city Diffa
# meteorite Gasseltepaoua and nearest city Djibo
# meteorite Glanerbrug and nearest city Münster
# meteorite Glatton and nearest city Peterborough
# meteorite Gorlovka and nearest city Horlivka
# meteorite Granes and nearest city Perpignan
# meteorite Grimsby and nearest city Hamilton
# meteorite Grefsheim and nearest city Hamar
# meteorite Guangmingshan and nearest city Zhuanghe
# meteorite Guangnan and nearest city Xingyi
# meteorite Guangrao and nearest city Buizhou
# meteorite Guibga and nearest city Kaya
# meteorite Gujargaon and nearest city Ujjain
# meteorite Gujba and nearest city Damaturu
# meteorite Gursum and nearest city Harar
# meteorite Hamlet and nearest city Plymouth
# meteorite Harleton and nearest city Marshall
# meteorite Haverö and nearest city Turku
# meteorite Hiroshima and nearest city Hiroshima
# meteorite Hoima and nearest city Hoima
# meteorite Hökmark and nearest city Skellefteå
# meteorite Hotse and nearest city Puyang
# meteorite Hoxie and nearest city Colby
# meteorite Huaxi and nearest city Guiyang
# meteorite Ibitira and nearest city Divinópolis
# meteorite Idutywa and nearest city Umtata
# meteorite Iguaracu and nearest city Maringá
# meteorite Ijopega and nearest city Goroka
# meteorite Innisfree and nearest city Vegreville
# meteorite Inner Mongolia and nearest city Hohhot
# meteorite Ipiranga and nearest city Foz do Iguaçu
# meteorite Ishinga and nearest city Tukuyu
# meteorite Itqiy and nearest city Bir Mogrein
# meteorite Jartai and nearest city Wuhai
# meteorite Jesenice and nearest city Jesenice
# meteorite Jiange and nearest city Mianyang
# meteorite Jodiya and nearest city Rajkot
# meteorite Jilin and nearest city Jiutai
# meteorite Jolomba and nearest city Calucinga
# meteorite Juancheng and nearest city Heze
# meteorite Jumapalo and nearest city Madiun
# meteorite Junan and nearest city Linyi
# meteorite Juromenha and nearest city Badajoz
# meteorite Kabo and nearest city Kano
# meteorite Kaidun and nearest city Al Mukalla
# meteorite Kalaba and nearest city Moba
# meteorite Kandahar (Afghanistan) and nearest city Kandahar
# meteorite Kaprada and nearest city Silvassa
# meteorite Karatu and nearest city Oldeani
# meteorite Karloowala and nearest city Dera Ismail Khan
# meteorite Kasauli and nearest city Muzaffarnagar
# meteorite Katagum and nearest city Azare
# meteorite Kayakent and nearest city Polatlı
# meteorite Kavarpura and nearest city Kota
# meteorite Kemer and nearest city Rodos
# meteorite Kendrapara and nearest city Cuttack
# meteorite Kidairat and nearest city En Nuhud
# meteorite Kiel and nearest city Kiel
# meteorite Kiffa and nearest city Kiffa
# meteorite Kilabo and nearest city Nguru
# meteorite Kingai and nearest city Niyala
# meteorite Kitchener and nearest city Kitchener
# meteorite Kobe and nearest city Kōbe
# meteorite Kokubunji and nearest city Takamatsu
# meteorite Košice and nearest city Košice
# meteorite Kulak and nearest city Chaman
# meteorite Kunya-Urgench and nearest city Koneurgench
# meteorite Kutais and nearest city Apsheronsk
# meteorite La Criolla and nearest city Concordia
# meteorite Lahrauli and nearest city Faizabad
# meteorite Lanxi and nearest city Lanxi
# meteorite Laochenzhen and nearest city Jieshou
# meteorite Leighlinbridge and nearest city Kilkenny
# meteorite Lichtenberg and nearest city Mahikeng
# meteorite Lishui and nearest city Maanshan
# meteorite Lohawat and nearest city Jodhpur
# meteorite Lorton and nearest city Alexandria
# meteorite Lost City and nearest city Tahlequah
# meteorite Louisville and nearest city Shively
# meteorite Lunan and nearest city Kunming
# meteorite Lusaka and nearest city Moba
# meteorite Machinga and nearest city Zomba
# meteorite Madhipura and nearest city Rajbiraj
# meteorite Magombedze and nearest city Masvingo
# meteorite Mahadevpur and nearest city Dibrugarh
# meteorite Maigatari-Danduma and nearest city Dutse
# meteorite Malakal and nearest city Malakal
# meteorite Manych and nearest city Elista
# meteorite Maribo and nearest city Svendborg
# meteorite Marilia and nearest city Marília
# meteorite Maromandia and nearest city Ambanja
# meteorite Mason Gully and nearest city Sekondi
# meteorite Maryville and nearest city Farragut
# meteorite Mayo Belwa and nearest city Yola
# meteorite Mbale and nearest city Mbale
# meteorite Medanitos and nearest city Belen
# meteorite Messina and nearest city Messina
# meteorite Mianchi and nearest city Luoyang
# meteorite Mifflin and nearest city Platteville
# meteorite Mihonoseki and nearest city Matsue
# meteorite Millbillillie and nearest city Meekatharra
# meteorite Min-Fan-Zhun and nearest city Nantong
# meteorite Molteno and nearest city Aliwal North
# meteorite Monahans (1998) and nearest city Monahans
# meteorite Monte das Fortes and nearest city Beja
# meteorite Monze and nearest city Mazabuka
# meteorite Morávka and nearest city Ostrava
# meteorite Moss and nearest city Moss
# meteorite Mount Tazerzait and nearest city Arlit
# meteorite Murchison and nearest city Shepparton
# meteorite Murray and nearest city Murray
# meteorite Muzaffarpur and nearest city Muzaffarpur
# meteorite Nadiabondi and nearest city Fada Ngourma
# meteorite Nantong and nearest city Nantong
# meteorite Naragh and nearest city Kashan
# meteorite Neagari and nearest city Kanazawa
# meteorite Nejo and nearest city Gimbi
# meteorite Neuschwanstein and nearest city Innsbruck
# meteorite New Halfa and nearest city Kassala
# meteorite New Orleans and nearest city Westwego
# meteorite Nikolskoe and nearest city Solnechnogorsk
# meteorite Ningbo and nearest city Ningbo
# meteorite Ningqiang and nearest city Guangyuan
# meteorite Noblesville and nearest city Noblesville
# meteorite Noventa Vicentina and nearest city Verona
# meteorite Nuevo Mercurio and nearest city Parras
# meteorite Ohuma and nearest city Abakaliki
# meteorite Okabe and nearest city Maebashi
# meteorite Omolon and nearest city Omolon
# meteorite Orlando and nearest city Winter Park
# meteorite Ouadangou and nearest city Bogandé
# meteorite Oued el Hadjar and nearest city Marrakesh
# meteorite Oum Dreyga and nearest city Fderik
# meteorite Ourique and nearest city Portimão
# meteorite Palca de Aparzo and nearest city Humahuaca
# meteorite Parambu and nearest city Tauá
# meteorite Paranaiba and nearest city Paranaíba
# meteorite Park Forest and nearest city Park Forest
# meteorite Patrimonio and nearest city Frutal
# meteorite Pavel and nearest city Turnovo
# meteorite Pê and nearest city Diébougou
# meteorite Peace River and nearest city Peace River
# meteorite Peckelsheim and nearest city Kassel
# meteorite Peekskill and nearest city Peekskill
# meteorite Pétèlkolé and nearest city Dori
# meteorite Patora and nearest city Raipur
# meteorite Piancaldoli and nearest city Bologna
# meteorite Piplia Kalan and nearest city Pali
# meteorite Pleşcoi and nearest city Buzău
# meteorite Portales Valley and nearest city Portales
# meteorite Pribram and nearest city Pizen
# meteorite Puerto Lápice and nearest city Toledo
# meteorite Qidong and nearest city Nantong
# meteorite Qingzhen and nearest city Guiyang
# meteorite Quija and nearest city Jiutai
# meteorite Raco and nearest city Tucumán
# meteorite Raghunathpura and nearest city Alwar
# meteorite Rahimyar Khan and nearest city Sadiqabad
# meteorite Ramsdorf and nearest city Münster
# meteorite Red Canyon Lake and nearest city Sonora
# meteorite Ras Tanura and nearest city Al-Qatif
# meteorite Revelstoke and nearest city Revelstoke
# meteorite Richland Springs and nearest city Brady
# meteorite Ruhobobo and nearest city Kisoro
# meteorite Sabrum and nearest city Comilla
# meteorite Saint-Séverin and nearest city Bordeaux
# meteorite Salem and nearest city Keizer
# meteorite Salzwedel and nearest city Braunschweig
# meteorite San Juan Capistrano and nearest city San Juan Capistrano
# meteorite San Michele and nearest city Ancona
# meteorite San Pedro de Quiles and nearest city Combarbalá
# meteorite San Pedro Jacuaro and nearest city Ciudad Hidalgo
# meteorite Santa Lucia (2008) and nearest city San Juan
# meteorite São Jose do Rio Preto and nearest city São José do Rio Preto
# meteorite Sayama and nearest city Kawagoe
# meteorite Schenectady and nearest city Scotia
# meteorite Senboku and nearest city Akita
# meteorite Seoni and nearest city Nagpur
# meteorite Sfax and nearest city Sfax
# meteorite Sheyang and nearest city Yancheng
# meteorite Shuangyang and nearest city Changchun
# meteorite Silao and nearest city Guanajuato
# meteorite Sinnai and nearest city Cagliari
# meteorite Sivas and nearest city Tokat
# meteorite Sixiangkou and nearest city Taizhou
# meteorite Soheria and nearest city Gorakhpur
# meteorite Sołtmany and nearest city Ełk
# meteorite Songyuan and nearest city Fuyu
# meteorite St. Louis and nearest city Jennings
# meteorite Ste. Marguerite and nearest city Lille
# meteorite Sterlitamak and nearest city Sterlitamak
# meteorite Stratford and nearest city Bridgeport
# meteorite St-Robert and nearest city Joliette
# meteorite Suchy Dul and nearest city Hradec Králové
# meteorite Suizhou and nearest city Anlu
# meteorite Sulagiri and nearest city Kolar
# meteorite Sutter's Mill and nearest city Placerville
# meteorite St.-Chinian and nearest city Béziers
# meteorite Sylacauga and nearest city Sylacauga
# meteorite Tahara and nearest city Hamamatsu
# meteorite Tagish Lake and nearest city Whitehorse
# meteorite Tambakwatu and nearest city Pasuruan
# meteorite Tamdakht and nearest city Marrakesh
# meteorite Taonan and nearest city Taonan
# meteorite Tathlith and nearest city Qal at Bishah
# meteorite Thika and nearest city Thika
# meteorite Thal and nearest city Bannu
# meteorite Thuathe and nearest city Maseru
# meteorite Tianzhang and nearest city Huaiyin
# meteorite Tillaberi and nearest city Tillabéri
# meteorite Tissint and nearest city Tiznit
